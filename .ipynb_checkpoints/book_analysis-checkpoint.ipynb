# %% [markdown]
# # Load the book

# %%
with open("miracle_in_the_andes.txt", "r") as file:
    book = file.read()

# %%
type(book)
# Out:
# str

# %% [markdown]
# # Find how many Chapters

# %%
import re

# %% [markdown]
# ### with string methods

# %%
book.count("Chapter") 
# this is not the best option since it will count all chapters in the same format as the one passed in the count() method
# Out:
# 11

# %% [markdown]
# ### with regex

# %%
# this is the best option since you get an accurate feedback. we use the re standard library

# %%
import re

# %%
pattern = re.compile("Chapter [0-9]+")
pattern
# Out:
# re.compile(r'Chapter [0-9]+', re.UNICODE)

# %%
info = re.findall(pattern, book)

# %%
info
# Out:
# ['Chapter 1',
#  'Chapter 2',
#  'Chapter 3',
#  'Chapter 4',
#  'Chapter 5',
#  'Chapter 6',
#  'Chapter 7',
#  'Chapter 8',
#  'Chapter 9',
#  'Chapter 10']

# %% [markdown]
# # Which are the sentences where "love" was used?

# %%
pattern = re.compile("[A-Z]{1}[^.]*[^a-zA-Z]+love[^a-zA-Z]+[^.]*.")
findings = re.findall(pattern, book)
len(findings)
# Out:
# 67

# %% [markdown]
# # What are the most used word

# %%
pattern = re.compile("[a-zA-Z]+")
pattern
# Out:
# re.compile(r'[a-zA-Z]+', re.UNICODE)

# %%
findings = re.findall(pattern, book.lower())
len(findings)
# Out:
# 86798

# %%
d = {}
for word in findings:
    if word in d.keys():
        d[word] = d[word] + 1
    else:
        d[word] = 1

# %%
sortWords = [(values, keys) for (keys, values) in d.items()]

# %%
# Out:
# [(11, 'chapter'),
#  (93, 'before'),
#  (800, 'it'),
#  (1430, 'was'),
#  (1, 'friday'),
#  (5346, 'the'),
#  (1, 'thirteenth'),
#  (2060, 'of'),
#  (8, 'october'),
#  (1226, 'we'),
#  (3, 'joked'),
#  (134, 'about'),
#  (1001, 'that'),
#  (15, 'flying'),
#  (101, 'over'),
#  (79, 'andes'),
#  (576, 'on'),
#  (57, 'such'),
#  (205, 'an'),
#  (1, 'unlucky'),
#  (88, 'day'),
#  (679, 'but'),
#  (34, 'young'),
#  (23, 'men'),
#  (88, 'make'),
#  (74, 'those'),
#  (3, 'kinds'),
#  (3, 'jokes'),
#  (333, 'so'),
#  (8, 'easily'),
#  (496, 'our'),
#  (26, 'flight'),
#  (941, 'had'),
#  (1, 'originated'),
#  (249, 'one'),
#  (9, 'earlier'),
#  (1419, 'in'),
#  (27, 'montevideo'),
#  (1169, 'my'),
#  (1, 'hometown'),
#  (53, 'its'),
#  (2, 'destination'),
#  (21, 'santiago'),
#  (26, 'chile'),
#  (1566, 'a'),
#  (2, 'chartered'),
#  (75, 'fairchild'),
#  (1, 'twin'),
#  (5, 'engine'),
#  (1, 'turboprop'),
#  (5, 'carrying'),
#  (49, 'rugby'),
#  (50, 'team'),
#  (51, 'old'),
# ...
